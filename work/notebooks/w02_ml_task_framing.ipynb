# %% [markdown]
# <a href="https://colab.research.google.com/github/Sameed-Gillani/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Sameed-Gillani/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# Classification / Scoring
# For Lane 6 (Momentum Prediction), I am framing this as a classification and risk-scoring task. Instead of just ranking pages by current traffic, the model will output a "Momentum Risk Score" or a binary prediction (At-Risk vs. Safe) indicating the probability of a page experiencing a severe traffic crash in the upcoming 30-day window.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# A binary label: 1 if a page's traffic drops by more than 20% in the target month compared to the previous month, and 0 otherwise.
# Proxy: If exact future daily traffic isn't perfectly stable to measure, the proxy I will use is the slope of the impression/click trendline over the last 90 days projected forward.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# Recall and Precision (Focusing heavily on Recall).
# My primary business goal is catching crashes before they happen. High recall ensures I don't miss pages that are about to lose their momentum. Precision matters so I don't waste writer resources updating perfectly fine pages, but missing a massive traffic crash (false negative) is costlier than doing an unnecessary content refresh (false positive).

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

# 1. Load the official dataset
url = "https://raw.githubusercontent.com/flyrank-bih/flyrank-ml-internship-starter/main/data/raw/content_refresh_anonymized.csv"
df = pd.read_csv(url)

# 2. Define the unit of analysis: One row = One specific page per client
# We will dynamically grab the first 4 columns so we don't get a KeyError
unit_df = df.iloc[:, :4].head(5).copy()

# 3. Sketch the future target column for my ML task (1 = At Risk of Crash, 0 = Safe)
unit_df['target_future_crash_risk'] = [1, 0, 0, 1, 0]

print("Unit of Analysis: One row = One specific page per Client.")
display(unit_df)
# Out:
# Unit of Analysis: One row = One specific page per Client.
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#    target_future_crash_risk
# 0                         1
# 1                         0
# 2                         0
# 3                         1
# 4                         0

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# A fixed rule (e.g., "update all pages older than 365 days with under 50 clicks") is reactive and static—it only catches pages that are already dead. Machine learning can weigh multiple interacting variables simultaneously—like the rate of impression decay, seasonal volatility, and age—to identify pages that are currently getting traffic but exhibit the hidden, multivariate mathematical signals of an imminent drop.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
