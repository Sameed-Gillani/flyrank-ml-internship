# %% [markdown]
# <a href="https://colab.research.google.com/github/Sameed-Gillani/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Sameed-Gillani/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# I am choosing Freestyle Lane 6: Growth / Recovery / Momentum Prediction. I want to move beyond static, reactive classification (e.g., "is this page dead right now?") and build a strict time-series model. Predicting a page's future momentum requires serious data discipline, specifically strict leakage audits, and provides massive proactive business value by warning teams before a traffic drop actually happens.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# Decision: Which seemingly healthy pages need immediate intervention because they are projected to lose momentum next month?
#
# Action: The content team prioritizes updating these "at-risk" pages before the traffic crashes.
#
# Cost of a wrong call: Wasting writer resources updating a page that would have been fine, while missing a page that actually crashes.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

# 1. Load the starter dataset from the official public starter repo
url = "https://raw.githubusercontent.com/flyrank-bih/flyrank-ml-internship-starter/main/data/raw/content_refresh_anonymized.csv"
df = pd.read_csv(url)

# 2. Pull 2-3 real numbers to support Lane 6
total_pages = len(df)
total_clients = df['client_id'].nunique()

print(f"Total pages available for time-series modeling: {total_pages}")
print(f"Number of pseudonymized client environments: {total_clients}")
print("\nConclusion for Lane 6: With tens of thousands of pages across multiple distinct clients, we have a robust dataset to track historical momentum and predict crashes before they happen.")
# Out:
# Total pages available for time-series modeling: 30000
# Number of pseudonymized client environments: 32
#
# Conclusion for Lane 6: With tens of thousands of pages across multiple distinct clients, we have a robust dataset to track historical momentum and predict crashes before they happen.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# I can claim directional, decision-support probabilities based on observed historical tracking patterns. I cannot claim causal proof of how the Google algorithm works or guarantee future traffic.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
